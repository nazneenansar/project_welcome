# %%
# !pip install tweepy
# !pip install twython

import tweepy
from time import sleep
from twython import Twython
  
auth = tweepy.OAuthHandler('zi72HOozS0h8PeaspfOFEshU1', '16RpVyyuxAreYmyUofNxpz2D1UoLM3x7Vlaca6JLbjmXHFNA6h')
auth.set_access_token('1072992350052474880-j4yKPQRrtYlYckq3PSgsGa97Hbvnb7', 'KNDHuCpZWufvetqZwRhciMSRtFo2LfcDrnVUOkTeZzTNq')
api = tweepy.API(auth)

twitter = Twython(
    'zi72HOozS0h8PeaspfOFEshU1',
    '16RpVyyuxAreYmyUofNxpz2D1UoLM3x7Vlaca6JLbjmXHFNA6h',
    '1072992350052474880-j4yKPQRrtYlYckq3PSgsGa97Hbvnb7',
    'KNDHuCpZWufvetqZwRhciMSRtFo2LfcDrnVUOkTeZzTNq'
)


# This is hastag which Twitter bot will
# search and retweet You can edit this with
# any hastag .For example : '# javascript'
  
QUERY = '# womenInSTEM'
  
# Twitter bot setting for liking Tweets
LIKE = False
  
# Twitter bot setting for following user who tweeted
FOLLOW = True
  
# Twitter bot sleep time settings in seconds. 
# For example SLEEP_TIME = 300 means 5 minutes.
# Please, use large delay if you are running bot 
# all the time so that your account does not
# get banned.
  
SLEEP_TIME = 3
  
print("Twitter bot which retweets, like tweets and follow users")
print("Bot Settings")
print("Follow users :", FOLLOW)

#message = "Helo World"
#twitter.update_status(status=message)
#print("Tweeted: %s" % message)

file1 = open('final-tweets-1.txt', 'r')
Lines = file1.readlines()
  
for line in Lines:
    try:
        # print('\nTweet by: @' + tweet.user.screen_name)
        # with open('the-zen-of-python.txt') as f:
        # contents = f.read() + str(# )
        message = str(line)
        twitter.update_status(status=message)
        # tweet.retweet()
        # print('Retweeted the tweet')
        
        sleep(SLEEP_TIME)
  
    except tweepy.TweepError as e:
        print(e.reason)
  
    except StopIteration:
        break
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: twython in /usr/local/lib/python3.7/dist-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from twython) (1.3.0)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from twython) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->twython) (3.1.1)
# Twitter bot which retweets, like tweets and follow users
# Bot Settings
# Follow users : True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-958c3ec8960f> in <module>()
#      59         # print('Retweeted the tweet')
#      60
# ---> 61         sleep(SLEEP_TIME)
#      62
#      63     except tweepy.TweepError as e:
#
# KeyboardInterrupt:
